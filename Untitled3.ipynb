# %% [markdown]
# <a href="https://colab.research.google.com/github/Antonio1206/TugasAnjas/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
from google.cloud import bigquery
auth.authenticate_user()
print('Authenticated')

project_id = "lc2hactiv" #GUNAKAN GCP PROJECT-ID KALIAN MASING-MASING
client = bigquery.Client(project=project_id)
# Out:
# Authenticated

# %%
df = client.query('''
SELECT *
FROM `ftds-hacktiv8-project.phase0_ftds_008_hck.beverage_sales`
''').to_dataframe()

# %%
df
# Out:
#            invoice_id        date  store_id       store_name   store_city  \
# 0     INV-58839200013  2023-05-26      6016       Metro Mall     CLARINDA
# 1     INV-56953900014  2023-03-24      6016       Metro Mall     CLARINDA
# 2     INV-56345300016  2023-03-03      6016       Metro Mall     CLARINDA
# 3     INV-32274100025  2020-11-27      6016       Metro Mall     CLARINDA
# 4     INV-32274100030  2020-11-27      6016       Metro Mall     CLARINDA
# ...               ...         ...       ...              ...          ...
# 6009  INV-46502900008  2022-04-14      4119  Peak Provisions  CEDAR FALLS
# 6010  INV-35080700016  2021-03-17      4119  Peak Provisions  CEDAR FALLS
# 6011  INV-20939700005  2019-07-30      4119  Peak Provisions  CEDAR FALLS
# 6012  INV-50461000007  2022-08-18      4119  Peak Provisions  CEDAR FALLS
# 6013  INV-51677600017  2022-09-29      4119  Peak Provisions  CEDAR FALLS
#
#               product_name   manufacturing_company  pack  unit_volume_ml  \
# ...

# %%
df_kota = client.query('''
SELECT
store_city
FROM `ftds-hacktiv8-project.phase0_ftds_008_hck.beverage_sales`
''').to_dataframe()

df_kota
# Out:
#        store_city
# 0        CLARINDA
# 1        CLARINDA
# 2        CLARINDA
# 3        CLARINDA
# 4        CLARINDA
# ...           ...
# 6009  CEDAR FALLS
# 6010  CEDAR FALLS
# 6011  CEDAR FALLS
# 6012  CEDAR FALLS
# 6013  CEDAR FALLS
#
# [6014 rows x 1 columns]

# %%
df_harga = client.query('''
SELECT
min(unit_retail_price) as minimun,
max(unit_retail_price) as maksimal
FROM
`ftds-hacktiv8-project.phase0_ftds_008_hck.beverage_sales`
''').to_dataframe()

df_harga
# Out:
#    minimun  maksimal
# 0     0.98      54.0

# %%
# no 4


df_produk = client.query('''

SELECT product_name as Nama_Prodak,
count (product_name) as total_terbanyak

FROM `ftds-hacktiv8-project.phase0_ftds_008_hck.beverage_sales`
group by product_name
order by total_terbanyak desc

''').to_dataframe()

df_produk
# Out:
#               Nama_Prodak  total_terbanyak
# 0    FruitFusion Quencher             1222
# 1    Sparkling Bliss Brew              539
# 2         VitaWave Splash              464
# 3      CitrusBurst Breeze              343
# 4         PureElixir Zest              308
# 5       CocoCrave Delight              293
# 6      SootheSip Serenity              262
# 7      RadiantRoot Revive              232
# 8       PineapplePop Fizz              205
# 9     OasisGlow Refresher              198
# 10       ZenZen Tea Blend              177
# 11    VelvetMist Infusion              149
# 12     MoonlitMocha Twist              146
# 13        AquaBerry Burst              142
# 14        SpicedApple Hug              135
# 15    CaramelCrunch Craze              123
# 16     FrostyMango Fusion              116
# 17        ChocoMint Bliss              112
# 18      HerbalHarmony Sip               99
# 19       BerryBlitz Chill               94
# 20      PeachyKeen Revive               88
# ...

# %%
import pandas as pd

df_00 = client.query('''
SELECT *
FROM `ftds-hacktiv8-project.phase0_ftds_008_hck.beverage_sales`
''').to_dataframe()

df_00
# Out:
#            invoice_id        date  store_id       store_name   store_city  \
# 0     INV-58839200013  2023-05-26      6016       Metro Mall     CLARINDA
# 1     INV-56953900014  2023-03-24      6016       Metro Mall     CLARINDA
# 2     INV-56345300016  2023-03-03      6016       Metro Mall     CLARINDA
# 3     INV-32274100025  2020-11-27      6016       Metro Mall     CLARINDA
# 4     INV-32274100030  2020-11-27      6016       Metro Mall     CLARINDA
# ...               ...         ...       ...              ...          ...
# 6009  INV-46502900008  2022-04-14      4119  Peak Provisions  CEDAR FALLS
# 6010  INV-35080700016  2021-03-17      4119  Peak Provisions  CEDAR FALLS
# 6011  INV-20939700005  2019-07-30      4119  Peak Provisions  CEDAR FALLS
# 6012  INV-50461000007  2022-08-18      4119  Peak Provisions  CEDAR FALLS
# 6013  INV-51677600017  2022-09-29      4119  Peak Provisions  CEDAR FALLS
#
#               product_name   manufacturing_company  pack  unit_volume_ml  \
# ...

# %%
# from datetime import date
# PANDAS


df_musim = client.query('''
SELECT date,
extract (month from date) as bulan
FROM `ftds-hacktiv8-project.phase0_ftds_008_hck.beverage_sales`
''').to_dataframe()

df_musim






# where (bulan > 1 and <4 as spring),
# where (bulan > 4 and <7 as summer),
# where (bulan > 1 and <4 as
# musim = {'Nama': ['Spring', 'Summer', 'Autumn', 'Winter'] }

# df = pd.DataFrame(musim)
# df
# Out:
#             date  bulan
# 0     2023-05-26      5
# 1     2023-03-24      3
# 2     2023-03-03      3
# 3     2020-11-27     11
# 4     2020-11-27     11
# ...          ...    ...
# 6009  2022-04-14      4
# 6010  2021-03-17      3
# 6011  2019-07-30      7
# 6012  2022-08-18      8
# 6013  2022-09-29      9
#
# [6014 rows x 2 columns]

# %%
# no.2 Berapa total barang yang terjual kepada toko Peak Provisions sepanjang tahun 2022?
# Peak Provisions
# store_name
# unit_sold
# menghitung unit sold yang

df_jual = client.query('''
SELECT store_name as Nama_toko, unit_sold as Barang_terjual

FROM `ftds-hacktiv8-project.phase0_ftds_008_hck.beverage_sales`
''').to_dataframe()

df_jual.count('store_name' == 'Peak Provisions')

# df_jumlah =df.count(unit_sold)
# Out:
# Nama_toko         6014
# Barang_terjual    6014
# dtype: int64
